# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np 
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import clear_output, Image as NoteImage, display
import PIL
from io import BytesIO
from scipy.ndimage.filters import gaussian_filter

# %%
#method to display image in ipython notebook directly. 
def imshow(inImage, fmt = 'jpeg'):
    f = BytesIO()
    PIL.Image.fromarray(inImage).save(f, fmt)
    display(NoteImage(data = f.getvalue()))

# %%
#we can use other method to display image: 
def imshow_1 (filename):
    img = NoteImage(filename)
    display(img)

# %%
#When the image file is read with the OpenCV function imread(), 
#the order of colors is BGR (blue, green, red)
#so we need to convert back to RGB order

img = cv.imread('tsukuba_fluorescent_L_00004.png')
imshow(img)

#you can see that below is BGR color image

# %%
img = cv.imread('tsukuba_fluorescent_L_00004.png')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB) #here is how you reverse the order

# %%
#now show the image: you can see that the color now is correct
imshow(img)

# %%
#we try other way to show the image. It is also fine. You can by yourself think about otherway to show the image
filename = 'tsukuba_fluorescent_L_00004.png'
imshow_1(filename)
